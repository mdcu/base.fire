# %% [markdown]
# <a href="https://colab.research.google.com/github/mdcu/base.fire/blob/master/R_data_structure.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # This is R notebook
# Unfortunately, ในนี้น่าจะ install package ใหม่ไม่ได้ครับ..
# ใช้ installed.packages() ดูได้ว่ามีอะไรให้ใช้บ้าง

# %%
# import common library
{library(ggplot2);}
# ไหนดูซิ update ไหม

# %% [markdown]
# ## ความเจ๋ง
# ทำบทเรียนในนี้ให้คน follow ได้สบายเลย

# %%
# warm up !
x<-seq(1000)
y<-x^2
plot(x,y)
# Out:
# plot without title
